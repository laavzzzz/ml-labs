# %%
correct = 70
total = 110

incorrect = total - correct
error_rate = incorrect / total

print("Error Rate:", error_rate)
print("Error Rate in %:", error_rate * 100)
# Out:
# Error Rate: 0.36363636363636365
# Error Rate in %: 36.36363636363637
