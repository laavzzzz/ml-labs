# %%
TP, FP, FN, TN = 22, 10, 8, 60

accuracy = (TP + TN) / (TP + TN + FP + FN)
precision = TP / (TP + FP)
recall = TP / (TP + FN)
f1 = 2 * precision * recall / (precision + recall)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.82
# Precision: 0.6875
# Recall: 0.7333333333333333
# F1 Score: 0.7096774193548386
